# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"C:\Users\Dell\Documents\vaishaliml\Diabeted age.csv")

# %%
dataset
# Out:
#    Diabeted Age    Gender
# 0             21     Male
# 1             56  Female
# 2             58   Female
# 3             67     Male
# 4             88   Female
# 5             45     Male
# 6             35     Male
# 7             38   Female
# 8             96   Female
# 9             52     Male

# %%
dataset['Gender'] = dataset['Gender'].str.strip().str.title() 
dataset['Gender'].replace({'Male':'0','Female':'1'},inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1048\4236597248.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['Gender'].replace({'Male':'0','Female':'1'},inplace=True)

# %%
dataset
# Out:
#    Diabeted Age  Gender
# 0             21      0
# 1             56      1
# 2             58      1
# 3             67      0
# 4             88      1
# 5             45      0
# 6             35      0
# 7             38      1
# 8             96      1
# 9             52      0

# %%
plt.scatter(x='Diabeted Age ',y='Gender',data=dataset)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(dataset[['Diabeted Age ']],dataset['Gender'],test_size=0.2)

# %%
len(x_train)
# Out:
# 8

# %%
len(x_test)
# Out:
# 2

# %%
x_test
# Out:
#    Diabeted Age
# 9             52
# 7             38

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array(['0', '0'], dtype=object)

# %%
x_test
# Out:
#    Diabeted Age
# 9             52
# 7             38

# %%
lr.predict([[60]])
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['1'], dtype=object)

# %%
lr.predict([[36]])
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['0'], dtype=object)
